# %%
import pandas as pd

# %% [markdown]
# #Data

# %% [markdown]
# ##Chargement

# %%
from google.colab import drive
drive.mount('/content/drive')

#TrainData
file_pathTr = "/content/drive/My Drive/TP1-NLP/twitter-2013train-A.txt"
column_names = ['Id', 'sentiment', 'text']
dataTr = pd.read_csv(file_pathTr, sep='\t', names=column_names)

#DevData
file_pathDv = "/content/drive/My Drive/TP1-NLP/twitter-2013dev-A.txt"
column_names = ['Id', 'sentiment', 'text']
dataDv = pd.read_csv(file_pathDv, sep='\t', names=column_names)

#TestData
file_pathTst = "/content/drive/My Drive/TP1-NLP/twitter-2013test-A.txt"
column_names = ['Id', 'sentiment', 'text']
dataTst = pd.read_csv(file_pathTst, sep='\t', names=column_names)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##Extraction

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from collections import Counter
from nltk.stem.snowball import EnglishStemmer
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')
nltk.download('stopwords')

def preprocess_text(text):
    # Suppression des liens, mentions, hashtags... et mettant les données en miniscule
    text = re.sub(r'@\w+', '', text)
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'#\w+', '', text)
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    text = text.lower()
    tokens = word_tokenize(text)
    # faire la lemmatisation avec WordNetLemmatizer et les stop words de NLTK
    stop_words = set(stopwords.words('english'))
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens if token not in stop_words]
    return ' '.join(lemmatized_tokens)

# Application du preprocess
dataTr['text'] = dataTr['text'].apply(preprocess_text)
dataDv['text'] = dataDv['text'].apply(preprocess_text)
dataTst['text'] = dataTst['text'].apply(preprocess_text)


corpus = ' '.join(dataTr['text'].astype(str).tolist())
words = word_tokenize(corpus)
word_counts = Counter(words)

words_at_least_once = [word for word, count in word_counts.items() if count >= 1]

print("Mots qui apparaissent au moins une fois dans le fichier :")
print(words_at_least_once)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Mots qui apparaissent au moins une fois dans le fichier :
# ['gas', 'house', 'hit', 'ium', 'going', 'chapel', 'hill', 'sat', 'theo', 'walcott', 'still', 'shituc', 'watch', 'rafa', 'johnny', 'deal', 'saturday', 'gsp', 'fanuc', 'hate', 'nick', 'diaz', 'canut', 'wait', 'february', 'iranian', 'general', 'say', 'israelus', 'iron', 'dome', 'missile', 'keep', 'talking', 'like', 'may', 'end', 'finding', 'tehranuc', 'mon', 'amour', 'obama', 'tried', 'establish', 'tie', 'mullah', 'via', 'barack', 'vote', 'mitt', 'romney', 'whole', 'movie', 'harry', 'ron', 'christmas', 'ohlawd', 'j', 'davlar', 'th', 'main', 'rival', 'team', 'poland', 'hopefully', 'make', 'successful', 'tough', 'week', 'training', 'tomorrow', 'actus', 'satusuc', 'deciding', 'want', 'go', 'collegeuc', 'applying', 'college', 'everything', 'stress', 'happy', 'valentine', 'day', 'trending', 'itus', 'june', 'smh', 'superbowl', 'dallasuc', 'dallas', 'ainut', 'winning', 'quarterback', 'owner', 'im', 'bringing', 'monster', 'load', 'candy', 'tomorrowuc', 'hope', 'doesnut', 'get', 'squiched', 'apple', 'softwareuc', 'retail', 'chief', 'overhaul', 'san', 'francisco', 'inc', 'ceo', 'tim', 'cook', 'monday', 'replaced', 'head', 'watched', 'sridevius', 'comeback', 'u', 'remember', 'sun', 'morning', 'nta', 'one', 'best', 'grader', 'kory', 'excited', 'touchdown', 'today', 'victor', 'cruzlol', 'nadal', 'confirmed', 'mexican', 'open', 'rafael', 'set', 'play', 'didnt', 'pop', 'yep', 'next', 'wednesday', 'come', 'shes', 'great', 'ill', 'tell', 'asked', 'hmmmm', 'november', 'odd', 'release', 'date', 'true', 'becomes', 'big', 'enough', 'maybe', 'could', 'sing', 'grammys', 'delisting', 'mko', 'global', 'terrorist', 'list', 'line', 'iran', 'campaign', 'oct', 'uc', 'irna', 'secretary', 'serge', 'amazing', 'he', 'actually', 'god', 'lanky', 'sex', 'saw', 'kasabian', 'noel', 'together', 'august', 'larry', 'bird', 'ranked', 'alltime', 'including', 'lebron', 'kobe', 'sayin', 'good', 'becky', 'thursday', 'fantastic', 'expect', 'lightmoderate', 'rain', 'e', 'visayas', 'cebuuc', 'boholuc', 'samar', 'leyte', 'chance', 'tonight', 'fair', 'weather', 'ticket', 'left', 'game', 'donut', 'miss', 'rematch', 'nfc', 'championship', 'ny', 'giant', 'afc', 'away', 'fan', 'stuff', 'ushe', 'said', 'nou', 'chant', 'bollock', 'balluc', 'turn', 'back', 'night', 'consisted', 'watching', 'grey', 'puppy', 'parent', 'throw', 'rager', 'hard', 'find', 'went', 'store', 'castle', 'cover', 'issue', 'none', 'search', 'nlcs', 'sfus', 'gon', 'na', 'cuuuuhraaaaaaaazeeeee', 'james', 'hall', 'live', 'indianapolis', 'decth', 'christ', 'church', 'apostolicu', 'tixs', 'adv', 'heat', 'cost', 'alot', 'moreand', 'plus', 'would', 'rather', 'see', 'austin', 'river', 'never', 'start', 'working', 'dream', 'goal', 'tomorrowtomorrow', 'comesif', 'mean', 'anything', 'uuc', 'act', 'vick', 'flaccouc', 'needed', 'upgrade', 'bencheduc', 'jennings', 'soon', 'thought', 'win', 'key', 'largouc', 'fl', 'yay', 'ur', 'neighbor', 'lisa', 'sip', 'n', 'hop', 'always', 'thurus', 'look', 'andy', 'android', 'little', 'much', 'fun', 'yesterday', 'oooh', 'nice', 'ti', 'tempting', 'lake', 'nikon', 'black', 'friday', 'huge', 'saving', 'aerial', 'view', 'cityuc', 'paris', 'la', 'vegasuc', 'vega', 'stripuc', 'yes', 'know', 'indio', 'v', 'cv', 'bell', 'jenelle', 'liesucst', 'alone', 'hospnow', 'sheus', 'saying', 'weird', 'keifferus', 'lmfao', 'as', 'nervesuc', 'class', 'hong', 'kong', 'time', 'mama', 'nov', 'mr', 'president', 'forever', 'chain', 'high', 'suck', 'compared', 'st', 'mohamed', 'morsiuc', 'egyptus', 'muslim', 'brotherhood', 'presidentuc', 'instructed', 'supreme', 'council', 'armed', 'force', 'cumon', 'avila', 'got', 'tagged', 'guy', 'kid', 'bill', 'murray', 'researching', 'royal', 'tenenbaums', 'think', 'boro', 'beat', 'swansea', 'sureuc', 'decemberjanuary', 'implode', 'first', 'grammy', 'awardsuc', 'held', 'domenico', 'modugno', 'frank', 'sinatra', 'peggy', 'lee', 'record', 'yearucwith', 'volare', 'birthday', 'vow', 'rd', 'anniversary', 'studied', 'friend', 'omg', 'jennette', 'life', 'fragile', 'weure', 'guaranteed', 'gi ...

# %% [markdown]
# ##Assigner

# %%
word_to_num_dict = {word: idx + 1 for idx, word in enumerate(words_at_least_once)}
print(word_to_num_dict)
# Out:
 'larry': 192, 'bird': 193, 'ranked': 194, 'alltime': 195, 'including': 196, 'lebron': 197, 'kobe': 198, 'sayin': 199, 'good': 200, 'becky': 201, 'thursday': 202, 'fantastic': 203, 'expect': 204, 'lightmoderate': 205, 'rain': 206, 'e': 207, 'visayas': 208, 'cebuuc': 209, 'boholuc': 210, 'samar': 211, 'leyte': 212, 'chance': 213, 'tonight': 214, 'fair': 215, 'weather': 216, 'ticket': 217, 'left': 218, 'game': 219, 'donut': 220, 'miss': 221, 'rematch': 222, 'nfc': 223, 'championship': 224, 'ny': 225, 'giant': 226, 'afc': 227, 'away': 228, 'fan': 229, 'stuff': 230, 'ushe': 231, 'said': 232, 'nou': 233, 'chant': 234, 'bollock': 235, 'balluc': 236, 'turn': 237, 'back': 238, 'night': 239, 'consisted': 240, 'watching': 241, 'grey': 242, 'puppy': 243, 'parent': 244, 'throw': 245, 'rager': 246, 'hard': 247, 'find': 248, 'went': 249, 'store': 250, 'castle': 251, 'cover': 252, 'issue': 253, 'none': 254, 'search': 255, 'nlcs': 256, 'sfus': 257, 'gon': 258, 'na': 259, 'cuuuuhraaaaaaaazeeeee': 260, 'james': 261, 'hall': 262, 'live': 263, 'indianapolis': 264, 'decth': 265, 'christ': 266, 'church': 267, 'apostolicu': 268, 'tixs': 269, 'adv': 270, 'heat': 271, 'cost': 272, 'alot': 273, 'moreand': 274, 'plus': 275, 'would': 276, 'rather': 277, 'see': 278, 'austin': 279, 'river': 280, 'never': 281, 'start': 282, 'working': 283, 'dream': 284, 'goal': 285, 't ...

# %% [markdown]
# ##Décompter et Convertisser

# %%
from sklearn.feature_extraction.text import CountVectorizer
#Pour ajuster l'index qui commence par 1, pour être compatible avec countVectorizer
adjusted_vocabulary = {word: (idx - 1) for word, idx in word_to_num_dict.items()}
vectorizer = CountVectorizer(vocabulary=adjusted_vocabulary)

X_train = vectorizer.fit_transform(dataTr['text'])
Y_train = dataTr['sentiment']

X_dev = vectorizer.transform(dataDv['text'])
Y_dev = dataDv['sentiment']

X_test = vectorizer.transform(dataTst['text'])
Y_test = dataTst['sentiment']

# %% [markdown]
# ##Appliquer

# %%
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

svm_classifier = SVC()
svm_classifier.fit(X_train, Y_train)

Y_dev_pred = svm_classifier.predict(X_dev)
Y_test_pred = svm_classifier.predict(X_test)

print("Evaluation du jeu de développement:\n", classification_report(Y_dev, Y_dev_pred))
print("Evaluation du jeu de test:\n", classification_report(Y_test, Y_test_pred))
# Out:
# Evaluation du jeu de développement:
#                precision    recall  f1-score   support
#
#     negative       0.70      0.11      0.19       340
#      neutral       0.57      0.89      0.70       739
#     positive       0.69      0.55      0.61       575
#
#     accuracy                           0.61      1654
#    macro avg       0.65      0.52      0.50      1654
# weighted avg       0.64      0.61      0.56      1654
#
# Evaluation du jeu de test:
#                precision    recall  f1-score   support
#
#     negative       0.77      0.12      0.21       559
#      neutral       0.55      0.94      0.69      1513
#     positive       0.83      0.48      0.61      1475
#
#     accuracy                           0.62      3547
#    macro avg       0.72      0.52      0.50      3547
# weighted avg       0.70      0.62      0.58      3547
